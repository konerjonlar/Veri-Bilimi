# %% [markdown]
# <a href="https://colab.research.google.com/github/konerjonlar/Veri-Bilimi/blob/main/Temel_Veri_Bilimi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dosya_adı = "AB_NYC_2019.csv"  # Yüklenen CSV dosyasının tam yolu
df = pd.read_csv(dosya_adı, delimiter= ",", encoding="UTF-8")
sns.set(rc={"figure.figsize":(20,10)})

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.size
# Out:
# 782320

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
df.describe().T
# Transpoz işlemi
# Out:
#                                   count        mean         std       min  \
# latitude                        48895.0   40.728949    0.054530  40.49979
# longitude                       48895.0  -73.952170    0.046157 -74.24442
# price                           48895.0  152.720687  240.154170   0.00000
# minimum_nights                  48895.0    7.029962   20.510550   1.00000
# number_of_reviews               48895.0   23.274466   44.550582   0.00000
# reviews_per_month               48895.0    2.302776    2.362699   0.01000
# calculated_host_listings_count  48895.0    7.143982   32.952519   1.00000
# availability_365                48895.0  112.781327  131.622289   0.00000
#
#                                      25%        50%         75%          max
# latitude                        40.69010   40.72307   40.763115     40.91306
# longitude                      -73.98307  -73.95568  -73.936275    -73.71299
# price                           69.00000  106.00000  175.000000  10000.00000
# minimum_nights                   1.00000    3.00000    5.000000   1250.00000
# number_of_reviews                1.00000    5.00000   24.000000    629.00000
# reviews_per_month                0.28000    1.22000    4.490000     58.50000
# calculated_host_listings_count   1.00000    1.00000    2.000000    327.00000
# availability_365                 0.00000   45.00000  227.000000    365.00000

# %%
df.drop(["name","id","host_id","host_name"],inplace= True, axis=1)

# %%
integers = ["minimum_nights","number_of_reviews", "calculated_host_listings_count", "availability_365"]

# outlier verilerden kurtulmak için
for column in integers:
  df[column] = pd.to_numeric(df[column], errors="coerce")

  max_value = (3*df[column].std()) + df[column].mean()  # finds the max value that is not going to be called not an outlier
  min_value = -((3*df[column].std()) + df[column].mean())  # finds the min value that is not going to be called not an outlier

  mean = df.loc[(df[column] > min_value) & (df[column] < max_value), column].mean()  # calculate the new mean of the column without the outlier values

  # if there is no outlier value then the mean will be np.nan in this situation don't need to do imputation
  if mean is not np.nan:
    df.loc[(df[column] < min_value) | (df[column] > max_value), column] = mean  # change outlier values with mean
    df[column].fillna(mean, inplace=True)  # also fill nan values with mean
  else:  # this condition means there is no outlier value in the column
    df[column].fillna(df[column].mean(), inplace=True)  # just fill nan values with mean

  df[column] = df[column].astype("int64")  # the type will be converted to int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   last_review                     48895 non-null  object
#  9   reviews_per_month               48895 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  int64
#  11  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# std        0.054530      0.046157    240.154170       20.510550
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           2.302776                        7.143982
# std            44.550582           2.362699                       32.952519
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.280000                        1.000000
# 50%             5.000000           1.220000                        1.000000
# 75%            24.000000           4.490000                        2.000000
# max           629.000000          58.500000                      327.000000
#
#        availability_365
# count      48895.000000
# mean         112.781327
# std          131.622289
# min            0.000000
# 25%            0.000000
# 50%           45.000000
# 75%          227.000000
# max          365.000000

# %%
for col in df.columns:
    eksik_deger_sayisi = df[col].isnull().sum()
    print("{:<30}: {:>5} adet eksik değer bulunmaktadır.".format(col, eksik_deger_sayisi))
# Out:
# neighbourhood_group           :     0 adet eksik değer bulunmaktadır.
# neighbourhood                 :     0 adet eksik değer bulunmaktadır.
# latitude                      :     0 adet eksik değer bulunmaktadır.
# longitude                     :     0 adet eksik değer bulunmaktadır.
# room_type                     :     0 adet eksik değer bulunmaktadır.
# price                         :     0 adet eksik değer bulunmaktadır.
# minimum_nights                :     0 adet eksik değer bulunmaktadır.
# number_of_reviews             :     0 adet eksik değer bulunmaktadır.
# last_review                   :     0 adet eksik değer bulunmaktadır.
# reviews_per_month             :     0 adet eksik değer bulunmaktadır.
# calculated_host_listings_count:     0 adet eksik değer bulunmaktadır.
# availability_365              :     0 adet eksik değer bulunmaktadır.

# %%
floats = ["price","reviews_per_month","calculated_host_listings_count","latitude","longitude"]

for column in floats:
  df[column] = pd.to_numeric(df[column],errors="coerce")

  max_value = (3*df[column].std()) + df[column].mean()
  min_value = -((3*df[column].std()) + df[column].mean())

  mean = df.loc[(df[column] > min_value) & (df[column] < max_value), column].mean()

  if mean is not np.nan:
    df.loc[(df[column] < min_value) | (df[column] > max_value), column] = mean
    df[column].fillna(mean, inplace=True)
  else:
    df[column].fillna(df[column].mean(),inplace=True)

  df[column] = df[column].astype("float64")

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  float64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   last_review                     48895 non-null  object
#  9   reviews_per_month               48895 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  float64
#  11  availability_365                48895 non-null  int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.5+ MB

# %%
sns.histplot(df["price"], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df.groupby("room_type")["room_type"].value_counts()
# Out:
# room_type        room_type
# Entire home/apt  Entire home/apt    25409
# Private room     Private room       22326
# Shared room      Shared room         1160
# Name: room_type, dtype: int64

# %%
for key,value in df.groupby(by="room_type")["room_type"].value_counts().items():
  if value == 1 :
    df.loc[df["room_type"]==key[0], "room_type"] = "unknown_type"
df.groupby(by="room_type")["room_type"].value_counts()
# Out:
# room_type        room_type
# Entire home/apt  Entire home/apt    25409
# Private room     Private room       22326
# Shared room      Shared room         1160
# Name: room_type, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
object_columns = df.select_dtypes("object").columns
object_columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type', 'last_review'], dtype='object')

# %%
for column in object_columns:
  df[column] = df[column].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48884 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48884 non-null  category
#  1   neighbourhood                   48884 non-null  category
#  2   latitude                        48884 non-null  float64
#  3   longitude                       48884 non-null  float64
#  4   room_type                       48884 non-null  category
#  5   price                           48884 non-null  float64
#  6   minimum_nights                  48884 non-null  int64
#  7   number_of_reviews               48884 non-null  int64
#  8   last_review                     48884 non-null  category
#  9   reviews_per_month               48884 non-null  float64
#  10  calculated_host_listings_count  48884 non-null  float64
#  11  availability_365                48884 non-null  int64
# dtypes: category(4), float64(5), int64(3)
# memory usage: 3.7 MB

# %%
df.describe().T
# Out:
#                                   count        mean         std       min  \
# latitude                        48884.0   40.728758    0.054227  40.49979
# longitude                       48884.0  -73.952176    0.046159 -74.24442
# price                           48884.0  138.778373  107.122447  10.00000
# minimum_nights                  48884.0    5.888450    8.885660   1.00000
# number_of_reviews               48884.0   18.178729   29.337335   0.00000
# reviews_per_month               48884.0    2.279223    2.300630   0.01000
# calculated_host_listings_count  48884.0    2.235228    3.635484   1.00000
# availability_365                48884.0  112.779498  131.627271   0.00000
#
#                                      25%         50%        75%        max
# latitude                        40.69010   40.723080   40.76300   40.89245
# longitude                      -73.98308  -73.955685  -73.93629  -73.71299
# price                           69.00000  106.000000  175.00000  860.00000
# minimum_nights                   1.00000    3.000000    5.00000   68.00000
# number_of_reviews                1.00000    5.000000   20.00000  156.00000
# reviews_per_month                0.28000    1.220000    4.41000    9.39000
# calculated_host_listings_count   1.00000    1.000000    2.00000   34.00000
# availability_365                 0.00000   45.000000  227.00000  365.00000

# %%
df.pivot_table(values=["number_of_reviews", "availability_365", "price"],
               columns="room_type",
               aggfunc=np.mean)
# Out:
# room_type          Entire home/apt  Private room  Shared room
# availability_365        111.926241    111.203638   161.873057
# number_of_reviews        18.325029     18.205072    14.461140
# price                   190.420198     83.748507    66.367110

# %%
# Verileri görselleştirerek daha iyi anlamak için bazı grafikler oluşturma
sns.countplot(x='neighbourhood_group', data=df)
plt.title('Airbnb New York 2019 - Mahalle Dağılımı')
plt.show()

# %%
# en popüler oda türlerini görelim.
df['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
# En yüksek fiyatlı ve en düşük fiyatlı 10 odayı görelim.
en_yuksek_fiyatli = df.nlargest(10, 'price')
en_yuksek_fiyatli[ 'price']
# Out:
# 9151     10000.0
# 17692    10000.0
# 29238    10000.0
# 6530      9999.0
# 12342     9999.0
# 40433     9999.0
# 30268     8500.0
# 4377      8000.0
# 29662     7703.0
# 42523     7500.0
# Name: price, dtype: float64

# %%
en_dusuk_fiyatli = df.nsmallest(10, 'price')
en_dusuk_fiyatli[ 'price']

# Fiyatı olan verilerin eleyelim.
# Out:
# 23161    0.0
# 25433    0.0
# 25634    0.0
# 25753    0.0
# 25778    0.0
# 25794    0.0
# 25795    0.0
# 25796    0.0
# 26259    0.0
# 26841    0.0
# Name: price, dtype: float64

# %%
# Fiyatı 0 olan değerleri eleyerek güncellenmiş veri setini oluşturma
df = df[df['price'] > 0]

# Güncellenmiş veri setinin boyutunu kontrol edelim
print("Güncellenmiş veri setinin boyutu:", df.shape)
# Out:
# Güncellenmiş veri setinin boyutu: (48884, 12)

# %% [markdown]
# Sayısal Değerlerin Dağılımı: Histogram

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['price'], kde=False, bins=30)
plt.xlabel('Fiyat')
plt.ylabel('Sayı')
plt.title('Fiyat Dağılımı')
plt.xlim(0, 1000)  # Fiyat ekseni 0 ile 1.000 arasında olacak
plt.show()

# %% [markdown]
# Kategorik Değerlerin Dağılımı: Countplot

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='neighbourhood_group', data=df)
plt.xlabel('Mahalle Grupları')
plt.ylabel('Sayı')
plt.title('Mahalle Gruplarına Göre Konaklama Sayısı')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# İlişki Gösterme: Scatter Plot

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='latitude', y='longitude', data=df, hue='neighbourhood_group', alpha=0.5)
plt.xlabel('Enlem')
plt.ylabel('Boylam')
plt.title('Mahalle Gruplarına Göre Enlem ve Boylam Dağılımı')
plt.legend(title='Mahalle Grupları', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Kategorik Değerlerin Ortlama Fiyata Etkisi: Bar Plot

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='room_type', y='price', data=df)
plt.xlabel('Oda Türü')
plt.ylabel('Ortalama Fiyat')
plt.title('Oda Türlerine Göre Ortalama Fiyat')
plt.show()

# %% [markdown]
#     Korelasyon Matrisi: Heatmap

# %%
plt.figure(figsize=(10, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Korelasyon Matrisi')
plt.show()
# Out:
# <ipython-input-59-0f58cbf24bd6>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
